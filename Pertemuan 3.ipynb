# %%
Nama = "Frea Nadira Solihah"
Nim = "0110123274"
Kelas = "SI03"
No_telp = "085892384804"
Alamat = """Jl. M. Yusuf Raya no. 88 Gg. H. Entong, Mekarjaya, Sukmajaya, Depok, Jawa Barat 16411"""

print(f"Nama saya adalah {Nama} \nNim saya adalah {Nim} \nSaya dari kelas {Kelas} \nNomor telepon saya {No_telp} \nAlamat saya di {Alamat}")
# Out:
# Nama saya adalah Frea Nadira Solihah
# Nim saya adalah 0110123274
# Saya dari kelas SI03
# Nomor telepon saya 085892384804
# Alamat saya di Jl. M. Yusuf Raya no. 88 Gg. H. Entong, Mekarjaya, Sukmajaya, Depok, Jawa Barat 16411

# %%
Nama = "Nur Suci Pramidha"
Nim = "0110123031"
Kelas = "SI03"
No_telp = "081398047025"
Alamat = """Jl. Mayjen H.R Edi Sukma No. 23 Km.17"""

print (f"Nama teman saya adalah {Nama} \nNim teman saya adalah {Nim} \nteman saya dari kelas {Kelas} \nNomor telepon teman saya {No_telp} \nAlamat teman saya di {Alamat}")
# Out:
# Nama teman saya adalah Nur Suci Pramidha
# Nim teman saya adalah 0110123031
# teman saya dari kelas SI03
# Nomor telepon teman saya 081398047025
# Alamat teman saya di Jl. Mayjen H.R Edi Sukma No. 23 Km.17

# %%
Tinggi_badan = 162
Berat_badan_ideal = Tinggi_badan - 100
print(f"Berat badan ideal saya adalah {Berat_badan_ideal}")
# Out:
# Berat badan ideal saya adalah 62

# %%
Celcius = 36
Fahrenheit = (Celcius * 9/5) + 32

print (f"jadi, 36 Celcius dalam skala Fahrenheit adalah {Fahrenheit} Fahrenheit")
# Out:
# jadi, 36 Celcius dalam skala Fahrenheit adalah 96.8 Fahrenheit

# %%
Jari2 = 28
Tinggi = 14

Luas_permukaan = int(2 * 22/7 * Jari2 * (Jari2 + Tinggi))

Keliling_alas = int(2 * 22/7 * Jari2)

print(f"Luas permukaan tabung adalah {Luas_permukaan} satuan luas")

print(f"Keliling alas tabung adalah {Keliling_alas} satuan panjang")
# Out:
# Luas permukaan tabung adalah 7392 satuan luas
# Keliling alas tabung adalah 176 satuan panjang
