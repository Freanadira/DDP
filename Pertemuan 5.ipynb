# %%
kendaraan = ['honda scoopy','motor','120cc','putih',2]
print(kendaraan)

kendaraan.append('20jt')
kendaraan.append('Scoopy')
print(kendaraan)

kendaraan.insert(2,'honda')
print(kendaraan)
# Out:
# ['honda scoopy', 'motor', '120cc', 'putih', 2]
# ['honda scoopy', 'motor', '120cc', 'putih', 2, '20jt', 'Scoopy']
# ['honda scoopy', 'motor', 'honda', '120cc', 'putih', 2, '20jt', 'Scoopy']

# %%
ket = '''Selamat datang di aplikasi menghitung luas bangun datar
Tentukan pilihan:
1. Untuk menghitung luas persegi
2. Untuk menghitung luas lingkaran
3. Untuk menghitung luas segitiga
Pilihan: '''

pilih = input(ket)

match pilih:
  case '1':
    print('Kamu memilih 1 untuk menghitung luas persegi')
    sisi = int(input('masukan sisi '))
    luasp = sisi*sisi
    print('Luas persegi yang sisinya', sisi, 'adalah', int(luasp))
  case '2':
    print('Kamu memilih 2 untuk menghitung luas lingkaran')
    jari2 = float(input('masukan jari-jari '))
    luasl = 3.14 * jari2 * jari2
    print('Luas lingkaran yang jari-jari nya', jari2, 'adalah', int(luasl))
  case '3':
    print('Kamu memilih 3 untuk menghitung luas segitiga')
    alas = int(input('masukan alas '))
    tinggi = int(input('masukan tinggi '))
    luass = 0.5 * alas * tinggi
    print('Luas segitiga yang alas nya', alas, 'dan tingginya', tinggi, 'adalah', int(luass))
  case _:
    print('salah memasukan pilihan')
# Out:
# Selamat datang di aplikasi menghitung luas bangun datar
# Tentukan pilihan:
# 1. Untuk menghitung luas persegi
# 2. Untuk menghitung luas lingkaran
# 3. Untuk menghitung luas segitiga
# Pilihan: 3
# Kamu memilih 3 untuk menghitung luas segitiga
# masukan alas 3
# masukan tinggi 4
# Luas segitiga yang alas nya 3 dan tingginya 4 adalah 6
