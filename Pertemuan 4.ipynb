# %%
a = 'saya'
Rok = 200000

if (Rok <= 200000):
  Keterangan = 'uang saya sudah cukup'
else:
  Keterangan = 'uang saya masih kurang'

print(a, 'bisa membeli rok seharga', Rok, 'sekarang, karena', Keterangan)
# Out:
# saya bisa membeli rok seharga 200000 sekarang, karena uang saya sudah cukup

# %%
a = 'saya'
Batagor = 30000

if (Batagor <= 5000):
  Keterangan = 'murah'
else:
  Keterangan = 'terlalu mahal'

print(a, 'tidak jadi membeli batagor seharga', Batagor, 'karena', Keterangan)
# Out:
# saya tidak jadi membeli batagor seharga 30000 karena terlalu mahal

# %%
a = 'saya'
Sisa = 9000

if (Sisa <= 4000):
  Keterangan = 'jalan kaki'
elif (Sisa<=10000):
  Keterangan = 'naik angkot'
else:
  Keterangan = 'naik grab'

print('sisa uang', a, 'sebesar', Sisa, 'jadi saya pulang ke rumah dengan', Keterangan)
# Out:
# sisa uang saya sebesar 9000 jadi saya pulang ke rumah dengan naik angkot

# %%
nama = 'Frea'
prodi = 'SI'
nim = '0110123274'
matkul = 'B.indo'
nilai = 95

if (nilai >90):
  keterangan = 'grade A'
elif (nilai >80):
  keterangan = 'grade B'
elif (nilai >70):
  keterangan = 'grade C'
else:
  keterangan = 'nilai dibawah nilai yang diatas grade D'

print('nama saya', nama, 'saya dari prodi', prodi, 'nim saya', nim, 'pada matkul', matkul, 'saya mendapatkan nilai sebesar', nilai, 'dan mendapatkan', keterangan)
# Out:
# nama saya Frea saya dari prodi SI nim saya 0110123274 pada matkul B.indo saya mendapatkan nilai sebesar 95 dan mendapatkan grade A
