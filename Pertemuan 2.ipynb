# %%
print("saya")
print("Nama: Frea Nadira Solihah")
print("Nim: 0110123274")
print("kelas: SI03")
print("Alamat: Jl. M. Yusuf Raya No.88")
# Out:
# saya
# Nama: Frea Nadira Solihah
# Nim: 0110123274
# kelas: SI03
# Alamat: Jl. M. Yusuf Raya No.88

# %%
print("teman")
print("Nama: Nur Suci Pramidha")
print("Nim: 0110123031")
print("kelas: SI03")
print("Alamat: kp. Caringin RT02/01")
# Out:
# teman
# Nama: Nur Suci Pramidha
# Nim: 0110123031
# kelas: SI03
# Alamat: kp. Caringin RT02/01

# %%
print(2+3)
# Out:
# 5

# %%
print(5-3)
# Out:
# 2

# %%
print(2*5)
# Out:
# 10

# %%
print(6/2)
# Out:
# 3.0
